# %%
import numpy as np
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
import pgmpy as pgm
from sklearn.decomposition import PCA
from sklearn.manifold import LocallyLinearEmbedding, TSNE

# %matplotlib notebook

# %%
data = np.load('../chorales_vectors_12.npy')
data.shape
# Out:
# (1764, 384)

# %%
LLE = LocallyLinearEmbedding(n_components = 2)
data_LLE = LLE.fit_transform(data)
plt.scatter(data_LLE[:,0], data_LLE[:,1])

# %%
import useful
tsne = TSNE(n_components=3, verbose = 1, perplexity = 30.0, n_iter = 1000)
data_tsne = tsne.fit_transform(data)
plt.scatter(data_tsne[:,0], data_tsne[:,1])

#useful.scatter_3d(
#    data_tsne[:, :3].T, 
#    rcParams=matplotlib.rcParams)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1764 samples in 0.019s...
# [t-SNE] Computed neighbors for 1764 samples in 1.573s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1764
# [t-SNE] Computed conditional probabilities for sample 1764 / 1764
# [t-SNE] Mean sigma: 2.362903
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.660080
# [t-SNE] Error after 900 iterations: 1.576048
# <img src="data:image/png;base64,..." width="2400">
