# %%
import numpy as np
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation, rc
from IPython.display import HTML
import pgmpy as pgm
from sklearn.decomposition import PCA
import useful
from sklearn.manifold import LocallyLinearEmbedding

# %matplotlib notebook
#matplotlib.rcParams['figure.figsize'] = [16, 9]
#matplotlib.rcParams['figure.dpi'] = 150

# %%
data = np.load('../chorales_vectors_12.npy')
data.shape
# Out:
# (1764, 384)

# %%
pca = PCA(n_components=100)
data_tr = pca.fit_transform(data)

# %%
data_tr.shape
# Out:
# (1764, 100)

# %%
import useful

useful.scatter_3d(
    data_tr[:, :3].T, 
    rcParams=matplotlib.rcParams)
# Out:
# <img src="data:image/png;base64,..." width="3200">

# %% [markdown]
# Here, we will perform a different dimensionality reduction technique because the data exists in a non-linear manifold.

# %%
# Create a LocallyLinearEmbedding Object

LLE = LocallyLinearEmbedding(n_components = 3)
data_LLE = LLE.fit_transform(data)
data_LLE[:5,:]
# Out:
# array([[0.00645944, 0.03304991],
#        [0.01304746, 0.03007683],
#        [0.00890633, 0.03100045],
#        [0.00223117, 0.03193651],
#        [0.01237879, 0.03060117]])

# %%
plt.scatter(data_LLE[:,0], data_LLE[:,1], 'r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-16407674e952> in <module>()
# ----> 1 plt.scatter(data_LLE[:,0], data_LLE[:,1], 'r')
#
# /Users/abhidevathi/anaconda3/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3473                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3474                          linewidths=linewidths, verts=verts,
# -> 3475                          edgecolors=edgecolors, data=data, **kwargs)
#    3476     finally:
#    3477         ax._hold = washold
#
# /Users/abhidevathi/anaconda3/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.pyc in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2360
#    2361         patches = super(Axes3D, self).scatter(
# ...
